# %%
# !git clone https://github.com/maryam-marzban-it/bigdata_projekt
# Out:
# Cloning into 'bigdata_projekt'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 1), reused 6 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 1.26 MiB | 3.06 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !ls
# Out:
# bigdata_projekt  sample_data

# %%
# %cd bigdata_projekt
# Out:
# /content/bigdata_projekt

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	test.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git config --global user.email "mmarzban80@gmail.com"
# !git config --global user.name "maryam-marzban-it"

# %%
# !git add -A

# %%
# !git commit -m "ny kommentar"
# Out:
# [main cb4b050] ny kommentar
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 test.ipynb

# %%
# !git push https://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@github.com/maryam-marzban-it/bigdata_projekt.git
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 276 bytes | 276.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/maryam-marzban-it/bigdata_projekt.git
#    d0c9065..cb4b050  main -> main

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !ls
# Out:
# df_test.csv  iot_fitness_dataset.csv  raw_energydata.csv  README.md  test.ipynb

# %%
# !cp /content/drive/MyDrive/Colab \Notebooks/lab1.ipynb
